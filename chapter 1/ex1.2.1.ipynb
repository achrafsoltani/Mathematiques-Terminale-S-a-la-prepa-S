// %%
%use lib-ext

// %%
LATEX("\\frac{ 9 - \\frac{1}{3} + \\frac{5}{6} - \\frac{25}{4} }{ 2 + \\frac{1}{6} - \\frac{5}{12} } \\times \\frac{ 3 - \\frac{2}{5} }{ \\frac{5}{3} - 1 }")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
println("Let's simplify each bit on it's own")
LATEX("A = 9 - \\frac{1}{3} + \\frac{5}{6} - \\frac{25}{4}")
// Out:
// Let's simplify each bit on it's own
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("B = 2 + \\frac{1}{6} - \\frac{5}{12}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("C = \\frac{ 3 - \\frac{2}{5} }{ \\frac{5}{3} - 1 }")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("A = \\frac{114}{12} - \\frac{4}{12} + \\frac{10}{12} - \\frac{75}{12}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("A = \\frac{45}{12} = \\frac{5 * 3 * 3}{3 * 4} = \\frac{5 * 3}{4} = \\frac{15}{4}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("B = 2 + \\frac{1}{6} - \\frac{5}{12}  = \\frac{24}{12} + \\frac{2}{12} - \\frac{5}{12}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("B = \\frac{24+2-5}{12} = \\frac{21}{12}  = \\frac{7}{4}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("C = \\frac{ 3 - \\frac{2}{5} }{ \\frac{5}{3} - 1 }  = \\frac{ \\frac{15-2}{5} }{ \\frac{5-3}{3} }")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("C = \\frac{15-2}{5} \\times \\frac{3}{5-3} = \\frac{13}{5} \\times \\frac{3}{2}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("C = \\frac{39}{10}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
println("Let's reassemble all the pieces together")
LATEX("\\frac{A}{B} \\times C = \\frac{\\frac{15}{4}}{\\frac{7}{4}} \\times \\frac{39}{10}")
// Out:
// Let's reassemble all the pieces together
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("= \\frac{15}{4} \\times {\\frac{4}{7} \\times \\frac{39}{10}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("= \\frac{15}{7} \\times \\frac{39}{10}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("= \\frac{3}{7} \\times \\frac{39}{2}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("= \\frac{117}{14}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>
