// %%
%use lib-ext

// %%
LATEX("2 - (\\frac{3}{4}+\\frac{2}{3}) - (3 - (\\frac{5}{3}+\\frac{1}{4})) - (2 - (\\frac{2}{3}+\\frac{7}{4}))")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("2 - 3 - 2 - (\\frac{9+8}{12}) + (\\frac{20+3}{12}) + (\\frac{8+21}{12})")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("2 - 3 - 2 - (\\frac{17}{12}) + (\\frac{23}{12}) + (\\frac{29}{12})")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("- 3 + (\\frac{-17+23+29}{12})")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("- 3 + (\\frac{35}{12})")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("-\\frac{3 * 12}{12} + (\\frac{35}{12})")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("\\frac{-36+35}{12}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
LATEX("\\frac{-1}{12}")
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %%
println((-1.toDouble()) / 12)
// Out:
// -0.08333333333333333
